# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

llm = ChatOpenAI(model='gpt-4o-mini')

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

food_prompt = PromptTemplate(
    template="""
        What is one of the most popular food in {country}?
        Please return the food only
    """,
    input_variables=['country'],
)

# %%
food_chain = food_prompt | llm | StrOutputParser()

# %%
food_chain.invoke({'country': 'Korea'})
# Out:
# 'Kimchi'

# %%
from langchain_core.prompts import ChatPromptTemplate

recipe_prompt = ChatPromptTemplate.from_messages([
    ('system', '''Provide the recipe of the food that the user wants. Please return the recipe only as a numbered list'''),
    ('human', 'Can you give me the recipe for making {food}?')
])

# %%
recipe_chain = recipe_prompt | llm | StrOutputParser()

# %%
recipe_chain.invoke({'food': '비빔밥'})
# Out:
# '1. Gather the ingredients: \n   - 2 cups cooked rice\n   - 1 cup of assorted vegetables (such as carrots, spinach, bean sprouts, zucchini, and mushrooms)\n   - 1 cup of cooked or seasoned protein (such as bulgogi, tofu, or a fried egg)\n   - Gochujang (Korean chili paste)\n   - Sesame oil\n   - Sesame seeds\n   - Soy sauce (optional)\n   - Sliced scallions (optional)\n\n2. Prepare the vegetables:\n   - Julienne the carrots and zucchini.\n   - Blanch the spinach and bean sprouts separately in boiling water, then drain.\n   - Sauté the mushrooms in a pan with a little oil until cooked.\n\n3. Cook the protein:\n   - If using bulgogi, prepare by marinating slices of beef and then cooking in a skillet over medium-high heat until done.\n   - If using tofu, cube it and sauté until golden brown.\n\n4. Assemble the bibimbap:\n   - In a large bowl, place a serving of cooked rice as the base.\n   - Arrange the prepared vegetables and protein on top of the rice in sections for an appealing presentation.\n\n5. Add condiments:\n   - Spoon gochujang on top to taste.\n   - Drizzle sesame oil over everything.\n   - Sprinkle sesame seeds and sliced scallions for garnish.\n\n6. Serve:\n   - Mix all ingredients together before eating to combine the flavors.\n   - Enjoy your bibimbap with additional soy sauce if desired.'

# %%
final_chain = {'food': food_chain} | recipe_chain

# %%
final_chain.invoke({'country': 'Korea'})
# Out:
# '1. **Ingredients**:\n   - 1 medium Napa cabbage\n   - 1/2 cup sea salt (for brining)\n   - 4 cups water (for brining)\n   - 1 tablespoon grated ginger\n   - 4 cloves garlic, minced\n   - 1 tablespoon sugar\n   - 3 tablespoons fish sauce (or soy sauce for a vegan option)\n   - 1 tablespoon Korean red pepper flakes (gochugaru) – adjust to taste\n   - 4 green onions, chopped\n   - 1 small carrot, julienned (optional)\n   - 1 radish, julienned (optional)\n\n2. **Prepare the Cabbage**:\n   - Cut the Napa cabbage in half lengthwise, then cut each half into bite-sized pieces.\n   - In a large bowl, dissolve sea salt in water and submerge the cabbage pieces in the brine. Let it sit for about 2 hours, tossing occasionally.\n\n3. **Rinse and Drain**:\n   - After 2 hours, rinse the cabbage under cold water to remove excess salt. Drain well.\n\n4. **Make the Kimchi Paste**:\n   - In a bowl, combine grated ginger, minced garlic, sugar, fish sauce (or soy sauce), and Korean red pepper flakes. Mix until it forms a paste.\n\n5. **Combine Ingredients**:\n   - Add the drained cabbage, green onions, and any optional vegetables (carrot and radish) to the kimchi paste. Mix well to ensure all cabbage pieces are coated.\n\n6. **Pack into Jars**:\n   - Pack the kimchi mixture tightly into clean, airtight jars, leaving some space at the top for fermentation.\n\n7. **Ferment**:\n   - Leave the jars at room temperature for 1-5 days, depending on the temperature and desired fermentation level. Check daily to taste.\n\n8. **Refrigerate**:\n   - Once fermented to your liking, transfer the jars to the refrigerator. Kimchi can be enjoyed immediately but tastes even better after a few days in the fridge.\n\n9. **Serve**:\n   - Serve kimchi as a side dish or as an ingredient in various recipes. Enjoy!'
